# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/results/017feefa35d1e5a8d27d3b93a6d96d15.jpg',0)
cv2_imshow(img)

img = cv2.imread('/content/results/00a1940434d687a785be0acf2b0fbff3.jpg',0)
cv2_imshow(img)

img = cv2.imread('/content/results/003d41dd20f271d27219fe7ee6de727d.jpg',0)
cv2_imshow(img)

img = cv2.imread('/content/results/01c6f5ce934d00d6923c549671c36000.jpg',0)
cv2_imshow(img)

img = cv2.imread('/content/results/02147618f9a3ea98605fa68f9179c7a0.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=667x1000 at 0x7F226B0158D0>
# <PIL.Image.Image image mode=L size=1067x1600 at 0x7F226B015510>
# <PIL.Image.Image image mode=L size=833x1000 at 0x7F226B015310>
# <PIL.Image.Image image mode=L size=1201x1800 at 0x7F226B015310>
# <PIL.Image.Image image mode=L size=4334x6493 at 0x7F226B0155D0>
